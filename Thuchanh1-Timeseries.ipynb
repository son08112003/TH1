# %%
#Importing the Libraries
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler,PowerTransformer
from sklearn.decomposition import PCA
from sklearn.mixture import BayesianGaussianMixture,GaussianMixture
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn import metrics
import lightgbm as lgb
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
from sklearn import metrics
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 12
#      10 from sklearn.decomposition import PCA
#      11 from sklearn.mixture import BayesianGaussianMixture,GaussianMixture
# ---> 12 from yellowbrick.cluster import KElbowVisualizer
#      13 from sklearn.metrics import silhouette_score
#      14 from sklearn.cluster import KMeans
#
# ModuleNotFoundError: No module named 'yellowbrick'

# %%
df=pd.read_csv("../Gia SMP va SMPcap 2021(Giá thị trường SMP).csv", encoding="latin-1", sep =';')

# %%
feats= ['4']

# %%
from sklearn.preprocessing import StandardScaler
transformer = StandardScaler()
X=transformer.fit_transform(np.array(df[feats]).reshape(-1,1))

# %%
BGM = BayesianGaussianMixture(n_components=7,covariance_type='full',random_state=1,n_init=15)
# fit model and predict clusters
preds = BGM.fit_predict(X)
df["Clusters"]= preds

# %%
pp=BGM.predict_proba(X)# Calcualting the probabilities of each prediction
df_new=pd.DataFrame(X,columns=feats)
df_new[[f'predict_proba_{i}' for i in range(7)]]=pp # creating new dataframe columns of probabilites
df_new['preds']=preds
df_new['predict_proba']=np.max(pp,axis=1)
df_new['predict']=np.argmax(pp,axis=1)

train_index=np.array([])
for n in range(7):
    n_inx=df_new[(df_new.preds==n) & (df_new.predict_proba > 0.68)].index
    train_index = np.concatenate((train_index, n_inx))

# %%
#ricopue's notebook's code snippet
from sklearn.model_selection import StratifiedKFold
X_new=df_new.loc[train_index][feats]
y=df_new.loc[train_index]['preds']

params_lgb = {'learning_rate': 0.06,'objective': 'multiclass','boosting': 'gbdt','n_jobs': -1,'verbosity': -1, 'num_classes':7}

model_list=[]

gkf = StratifiedKFold(11)
for fold, (train_idx, valid_idx) in enumerate(gkf.split(X_new,y)):

    tr_dataset = lgb.Dataset(X_new.iloc[train_idx],y.iloc[train_idx],feature_name = feats)
    vl_dataset = lgb.Dataset(X_new.iloc[valid_idx],y.iloc[valid_idx],feature_name = feats)

    model = lgb.train(params = params_lgb,
                train_set = tr_dataset,
                valid_sets =  vl_dataset,
                num_boost_round = 5000,
                callbacks=[ lgb.early_stopping(stopping_rounds=300, verbose=False), lgb.log_evaluation(period=200)])

    model_list.append(model)
# Out:
# [200]	valid_0's multi_logloss: 0.000151726
# [400]	valid_0's multi_logloss: 0.000151726
# [200]	valid_0's multi_logloss: 0.000153686
# [400]	valid_0's multi_logloss: 0.000153686
# [200]	valid_0's multi_logloss: 0.000154034
# [400]	valid_0's multi_logloss: 0.000154034
# [200]	valid_0's multi_logloss: 0.000156754
# [400]	valid_0's multi_logloss: 0.000156754
# [200]	valid_0's multi_logloss: 0.000153261
# [400]	valid_0's multi_logloss: 0.000153261
# [200]	valid_0's multi_logloss: 0.00015524
# [400]	valid_0's multi_logloss: 0.00015524
# [200]	valid_0's multi_logloss: 0.000155472
# [400]	valid_0's multi_logloss: 0.000155472
# [200]	valid_0's multi_logloss: 9.92419e-06
# [400]	valid_0's multi_logloss: 9.8222e-06
# [600]	valid_0's multi_logloss: 9.75475e-06
# [800]	valid_0's multi_logloss: 9.70667e-06
# [1000]	valid_0's multi_logloss: 9.67072e-06
# [1200]	valid_0's multi_logloss: 9.64285e-06
# [1400]	valid_0's multi_logloss: 9.62062e-06
# [1600]	valid_0's multi_logloss: 9.60248e-06
# [1800]	valid_0's multi_logloss: 9.5874e-06
# [2000]	valid_0's multi_logloss: 9.57468e-06
# [2200]	valid_0's multi_logloss: 9.5638e-06
# [2400]	valid_0's multi_logloss: 9.55439e-06
# [2600]	valid_0's multi_logloss: 9.54618e-06
# [2800]	valid_0's multi_logloss: 9.53894e-06
# [3000]	valid_0's multi_logloss: 9.53252e-06
# [3200]	valid_0's multi_logloss: 9.52679e-06
# [3400]	valid_0's multi_logloss: 9.52163e-06
# [3600]	valid_0's multi_logloss: 9.51698e-06
# [3800]	valid_0's multi_logloss: 9.51275e-06
# [4000]	valid_0's multi_logloss: 9.50889e-06
# [4200]	valid_0's multi_logloss: 9.50536e-06
# [4400]	valid_0's multi_logloss: 9.50212e-06
# [4600]	valid_0's multi_logloss: 9.49913e-06
# [4800]	valid_0's multi_logloss: 9.49636e-06
# [5000]	valid_0's multi_logloss: 9.49379e-06
# [200]	valid_0's multi_logloss: 0.000157332
# [400]	valid_0's multi_logloss: 0.000157332
# [200]	valid_0's multi_logloss: 0.0119762
# [400]	valid_0's multi_logloss: 0.0119762
# [200]	valid_0's multi_logloss: 0.02382

# %%
lgb_preds=0
for model in model_list:
    lgb_preds+=model.predict(df_new[feats])

# %%
labels=np.argmax(lgb_preds,axis=1)

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.subplot(label="bla")
sns.scatterplot(df[feats], marker='o');
ax.set_title("Before clustering");

# %%
fig = plt.figure(figsize=(10,8))
sns.scatterplot(df[feats], c=df["Clusters"], marker='o',cmap="rainbow");
ax.set_title("After Clustering");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-168-aa0dd817f4aa> in <cell line: 2>()
#       1 fig = plt.figure(figsize=(10,8))
# ----> 2 sns.scatterplot(df[feats], c=df["Clusters"], marker='o',cmap="rainbow");
#       3 ax.set_title("After Clustering");
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     629     kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
#     630
# --> 631     p.plot(ax, kwargs)
#     632
#     633     return ax
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in plot(self, ax, kws)
#     457         if self.legend:
#     458             attrs = {"hue": "color", "size": "s", "style": None}
# --> 459             self.add_legend_data(ax, _scatter_legend_artist, kws, attrs)
#     460             handles, _ = ax.get_legend_handles_labels()
#     461             if handles:
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in add_legend_data(self, ax, func, common_kws, attrs, semantic_kws)
#    1265                 if attr in kws:
#    1266                     level_kws[attr] = kws[attr]
# -> 1267             artist = func(label=label, **{"color": ".2", **common_kws, **level_kws})
#    1268             if _version_predates(mpl, "3.5.0"):
#    1269                 if isinstance(artist, mpl.lines.Line2D):
#
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py in _scatter_legend_artist(**kws)
#     878             line_kws["markeredgecolor"] = edgecolor
#     879
# --> 880     return mpl.lines.Line2D([], [], **line_kws)
#     881
#     882
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     452                 "parameter will become keyword-only %(removal)s.",
#     453                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454         return func(*args, **kwargs)
#     455
#     456     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     391         # update kwargs before updating data to give the caller a
#     392         # chance to init axes (and hence unit support)
# --> 393         self._internal_update(kwargs)
#     394         self._pickradius = pickradius
#     395         self.ind_offset = 0
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1221         The lack of prenormalization is to maintain backcompatibility.
#    1222         """
# -> 1223         return self._update_props(
#    1224             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225             "{prop_name!r}")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1197                         raise AttributeError(
#    1198                             errfmt.format(cls=type(self), prop_name=k))
# -> 1199                     ret.append(func(v))
#    1200         if ret:
#    1201             self.pchanged()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/__init__.py in method(self, *args, **kwargs)
#     254         @functools.wraps(getattr(cls, name))
#     255         def method(self, *args, **kwargs):
# --> 256             return getattr(self, name)(*args, **kwargs)
#     257         return method
#     258
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/lines.py in set_color(self, color)
#    1058         color : color
#    1059         """
# -> 1060         mcolors._check_color_like(color=color)
#    1061         self._color = color
#    1062         self.stale = True
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py in _check_color_like(**kwargs)
#     241     for k, v in kwargs.items():
#     242         if not is_color_like(v):
# --> 243             raise ValueError(f"{v!r} is not a valid value for {k}")
#     244
#     245
#
# ValueError: 0      0
# 1      0
# 2      0
# 3      0
# 4      2
#       ..
# 360    0
# 361    0
# 362    2
# 363    0
# 364    0
# Name: Clusters, Length: 365, dtype: int64 is not a valid value for color

# %%
pl = sns.countplot(x=np.argmax(lgb_preds,axis=1))
pl.set_title("Distribution Of The Clusters")
plt.show()

# %%
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Dropout
from keras.layers import LSTM

# %%
df['Ngày'] = pd.to_datetime(df['Ngày'], format='%d/%m/%Y')
df.sort_values(by='Ngày', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
test_size = df[df['Ngày'].dt.month==12].shape[0]
test_size
# Out:
# 31

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'orange'
plt.rc('axes',edgecolor='white')
plt.plot(df['Ngày'][:-test_size], df['4'][:-test_size], color='black', lw=2)
plt.plot(df['Ngày'][-test_size:], df['4'][-test_size:], color='blue', lw=2)
plt.title('4', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('4', fontsize=12)
plt.legend(['Training set', 'Test set'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %%
import plotly.express as px
fig = px.line(y=df['4'], x=df['Ngày'])
fig.update_traces(line_color='black')
fig.update_layout(xaxis_title="Ngày",
                  yaxis_title="4",
                  title={'text': "Data", 'y':0.95, 'x':0.5, 'xanchor':'center', 'yanchor':'top'},
                  plot_bgcolor='rgba(53,223,0,0.8)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ac41df51-8889-47eb-aa29-65999d3f52ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac41df51-8889-47eb-aa29-65999d3f52ae")) {                    Plotly.newPlot(                        "ac41df51-8889-47eb-aa29-65999d3f52ae",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"black","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-01-01T00:00:00","2021-01-02T00:00:00","2021-01-03T00:00:00","2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-09T00:00:00","2021-01-10T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-16T00:00:00","2021-01-17T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-23T00:00:00","2021-01-24T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-01-30T00:00:00","2021-01-31T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-06T00:00:00","2021-02-07T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-13T00:00:00","2021-02-14T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-20T00:00:00","2021-02-21T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-02-27T00:00:00","2021-02-28T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-06T00:00:00","2021-03-07T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-13T00:00:00","2021-03-14T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-20T00:00:00","2021-03-21T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-27T00:00:00","2021-03-28T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-02T00:00:00","2021-04-03T00:00:00","2021-04-04T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-10T00:00:00","2021-04-11T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-17T00:00:00","2021-04-18T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-24T00:00:00","2021-04-25T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-01T00:00:00","2021-05-02T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-08T00:00:00","2021-05-09T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-15T00:00:00","2021-05-16T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-22T00:00:00","2021-05-23T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-0 ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df['4'].values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %%
window_size = 15

# %%
train_data = df['4'][:-test_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

# %%
X_train = []
y_train = []

for i in range(window_size, len(train_data)):
    X_train.append(train_data[i-window_size:i, 0])
    y_train.append(train_data[i, 0])

# %%
test_data = df['4'][-test_size-window_size:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
X_test = []
y_test = []

for i in range(window_size, len(test_data)):
    X_test.append(test_data[i-window_size:i, 0])
    y_test.append(test_data[i, 0])

# %%
X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test  = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
def define_model():
    input1 = Input(shape=(window_size,1))
    x = LSTM(units = 64)(input1)
    x = Dense(32, activation='softmax')(x)
    dnn_output = Dense(1)(x)

    model = Model(inputs=input1, outputs=[dnn_output])
    model.compile(loss='mean_squared_error', optimizer='Nadam')
    model.summary()

    return model

# %%
model = define_model()
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.1, verbose=1)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 15, 1)]           0
#
#  lstm_1 (LSTM)               (None, 64)                16896
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 19009 (74.25 KB)
# Trainable params: 19009 (74.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 18/18 [==============================] - 3s 32ms/step - loss: 0.0588 - val_loss: 0.0239
# Epoch 2/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0281 - val_loss: 0.0158
# Epoch 3/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0256 - val_loss: 0.0177
# Epoch 4/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0260 - val_loss: 0.0156
# Epoch 5/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0254 - val_loss: 0.0157
# Epoch 6/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0251 - val_loss: 0.0157
# Epoch 7/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0248 - val_loss: 0.0157
# Epoch 8/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0242 - val_loss: 0.0155
# Epoch 9/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0236 - val_loss: 0.0161
# Epoch 10/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0227 - val_loss: 0.0154
# Epoch 11/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0223 - val_loss: 0.0170
# Epoch 12/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0213 - val_loss: 0.0171
# Epoch 13/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0201 - val_loss: 0.0174
# Epoch 14/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0193 - val_loss: 0.0164
# Epoch 15/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0188 - val_loss: 0.0157
# Epoch 16/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0182 - val_loss: 0.0157
# Epoch 17/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0178 - val_loss: 0.0159
# Epoch 18/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0176 - val_loss: 0.0167
# Epoch 19/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0170 - val_loss: 0.0158
# Epoch 20/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0168 - val_loss: 0.0162
# Epoch 21/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0166 - val_loss: 0.0165
# Epoch 22/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0160 - val_loss: 0.0162
# Epoch 23/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0157 - val_loss: 0.0173
# Epoch 24/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0154 - val_loss: 0.0171
# Epoch 25/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0152 - val_loss: 0.0185
# Epoch 26/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0147 - val_loss: 0.0181
# Epoch 27/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0146 - val_loss: 0.0169
# Epoch 28/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0140 - val_loss: 0.0177
# Epoch 29/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0148 - val_loss: 0.0171
# Epoch 30/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 0.0177
# Epoch 31/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 0.0181
# Epoch 32/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0140 - val_loss: 0.0197
# Epoch 33/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0135 - val_loss: 0.0171
# Epoch 34/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0136 - val_loss: 0.0172
# Epoch 35/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0138 - val_loss: 0.0176
# Epoch 36/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0134 - val_loss: 0.0173
# Epoch 37/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0130 - val_loss: 0.0173
# Epoch 38/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0133 - val_loss: 0.0175
# Epoch 39/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0132 - val_loss: 0.0198
# Epoch 40/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0128 - val_loss: 0.0173
# Epoch 41/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0180
# Epoch 42/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0199
# Epoch 43/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0130 - val_loss: 0.0189
# Epoch 44/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0130 - val_loss: 0.0191
# Epoch 45/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0132 - val_loss: 0.0193
# Epoch 46/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0127 - val_loss: 0.0178
# Epoch 47/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0179
# Epoch 48/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0180
# Epoch 49/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0179
# Epoch 50/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0174
# Epoch 51/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0178
# Epoch 52/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0119 - val_loss: 0.0185
# Epoch 53/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0119 - val_loss: 0.0187
# Epoch 54/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0191
# Epoch 55/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0121 - val_loss: 0.0189
# Epoch 56/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0119 - val_loss: 0.0178
# Epoch 57/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0183
# Epoch 58/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0116 - val_loss: 0.0180
# Epoch 59/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0178
# Epoch 60/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0116 - val_loss: 0.0179
# Epoch 61/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 0.0171
# Epoch 62/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0121 - val_loss: 0.0179
# Epoch 63/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0116 - val_loss: 0.0182
# Epoch 64/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0115 - val_loss: 0.0190
# Epoch 65/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0115 - val_loss: 0.0185
# Epoch 66/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0115 - val_loss: 0.0184
# Epoch 67/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 0.0181
# Epoch 68/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0112 - val_loss: 0.0179
# Epoch 69/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0114 - val_loss: 0.0180
# Epoch 70/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0110 - val_loss: 0.0188
# Epoch 71/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0113 - val_loss: 0.0201
# Epoch 72/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0112 - val_loss: 0.0190
# Epoch 73/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0112 - val_loss: 0.0189
# Epoch 74/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0111 - val_loss: 0.0181
# Epoch 75/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 0.0184
# Epoch 76/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0111 - val_loss: 0.0193
# Epoch 77/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0187
# Epoch 78/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0108 - val_loss: 0.0180
# Epoch 79/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0110 - val_loss: 0.0193
# Epoch 80/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0110 - val_loss: 0.0199
# Epoch 81/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 0.0190
# Epoch 82/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0108 - val_loss: 0.0186
# Epoch 83/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0108 - val_loss: 0.0187
# Epoch 84/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0106 - val_loss: 0.0196
# Epoch 85/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0110 - val_loss: 0.0200
# Epoch 86/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0104 - val_loss: 0.0189
# Epoch 87/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0105 - val_loss: 0.0197
# Epoch 88/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0105 - val_loss: 0.0198
# Epoch 89/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0106 - val_loss: 0.0199
# Epoch 90/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0101 - val_loss: 0.0204
# Epoch 91/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0105 - val_loss: 0.0199
# Epoch 92/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0101 - val_loss: 0.0200
# Epoch 93/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 0.0200
# Epoch 94/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0225
# Epoch 95/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 0.0193
# Epoch 96/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0103 - val_loss: 0.0204
# Epoch 97/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0108 - val_loss: 0.0200
# Epoch 98/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0106 - val_loss: 0.0210
# Epoch 99/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0210
# Epoch 100/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0224

# %%
result = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 337ms/step - loss: 0.0243
# 1/1 [==============================] - 0s 307ms/step

# %%
from sklearn.metrics import mean_absolute_percentage_error,accuracy_score,r2_score
MAPE = mean_absolute_percentage_error(y_test, y_pred)
Accuracy = 1-MAPE

# %%
print("Test Loss:", result)
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.024324946105480194
# Test MAPE: 2.318353523559508
# Test Accuracy: -1.3183535235595079

# %%
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'orange'
plt.rc('axes',edgecolor='white')
plt.plot(df['Ngày'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df['Ngày'].iloc[-test_size:], y_test_true, color='blue', lw=2)
plt.plot(df['Ngày'].iloc[-test_size:], y_test_pred, color='red', lw=2)
plt.title('Prediction', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('4', fontsize=12)
plt.legend(['Training Data', 'Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()
